# %% [markdown]
# <a href="https://colab.research.google.com/github/joe052/machine-learn/blob/main/intelCaseStudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1db08915-4d29-471e-9db1-b82a8c7a0c6e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1db08915-4d29-471e-9db1-b82a8c7a0c6e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('data.xlsx')

# %%
df.head()
# Out:
#    ConstCom  TimelyInf  TaskMgm  DeviceSt  Wellness  Athlete  Style  AmznP  \
# 0         3          2        3         3         2        3      3      1
# 1         6          6        6         6         5        3      1      1
# 2         7          4        4         4         6        4      1      0
# 3         7          5        4         5         5        4      4      1
# 4         7          4        2         6         3        2      4      1
#
#    Female  Degree  Income  Age
# 0       1       1       2   38
# 1       0       2       3   38
# 2       0       1       3   42
# 3       0       2       5   35
# 4       0       1       3   36

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ConstCom   1000 non-null   int64
#  1   TimelyInf  1000 non-null   int64
#  2   TaskMgm    1000 non-null   int64
#  3   DeviceSt   1000 non-null   int64
#  4   Wellness   1000 non-null   int64
#  5   Athlete    1000 non-null   int64
#  6   Style      1000 non-null   int64
#  7   AmznP      1000 non-null   int64
#  8   Female     1000 non-null   int64
#  9   Degree     1000 non-null   int64
#  10  Income     1000 non-null   int64
#  11  Age        1000 non-null   int64
# dtypes: int64(12)
# memory usage: 93.9 KB

# %%
(df['Female'] == 1).sum()
# (df['Female'] == 0).sum()
# Out:
# 566

# %%
df[df['Age'] == df['Age'].max()]
df[df['Age'] == df['Age'].min()]
# Out:
#      ConstCom  TimelyInf  TaskMgm  DeviceSt  Wellness  Athlete  Style  AmznP  \
# 52          5          7        3         6         5        6      4      0
# 79          5          5        2         4         5        7      4      0
# 378         4          4        2         4         5        6      4      1
# 440         7          4        5         6         5        7      4      1
# 475         4          5        2         7         5        6      6      1
# 593         2          3        2         5         5        6      6      0
# 768         6          4        3         7         5        6      4      0
# 770         5          7        4         6         5        6      4      1
# 802         5          5        5         3         6        5      4      1
# 859         5          4        5         4         4        5      4      1
# 862         6          5        5         4         4        4      5      0
# ...

# %%
df['Age'].mean()
# Out:
# 35.515

# %%
(df['Degree'] == 1).sum()
# Out:
# 668

# %%
df['Athlete'].value_counts().idxmax()
# Out:
# 4

# %%
df['Income'].value_counts().idxmax()
# Out:
# 3

# %%
df['Income'].mean()

# %%
df[df['Income'] == df['Income'].min()]
# Out:
#      ConstCom  TimelyInf  TaskMgm  DeviceSt  Wellness  Athlete  Style  AmznP  \
# 17          5          4        5         1         2        1      4      0
# 19          4          5        4         1         2        4      4      0
# 21          3          3        6         2         5        5      4      0
# 22          5          2        6         2         5        5      3      0
# 34          6          3        3         3         5        6      4      0
# 49          5          4        6         2         5        5      4      0
# 68          3          5        5         3         1        2      4      0
# 71          6          5        5         1         4        4      4      0
# 86          5          4        6         2         3        2      3      1
# 87          4          3        3         1         4        4      4      1
# 88          3          3        3         4         1        1      4      0
# ...

# %%
df['Style'].mean()
# Out:
# 4.299

# %%
(df['AmznP'] == 1).sum()
# Out:
# 564
